# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def entropy(p):
    return - p * np.log(p) - (1-p) * np.log(1-p)

# %%
x = np.linspace(0.001, 0.999, 200) #这里模拟p，因为log0无意义，所以我们不希望x == 0，不想x == 1，因为1-x == 0

# %%
plt.plot(x, entropy(x))
plt.show()
