# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.uniform(-3, 3, size = 100)
X = x.reshape(-1,1)

# %%
y = 0.5 * X**2 + X + np.random.normal( size = (100,1))
y.shape
# Out:
# (100, 1)

# %%
plt.scatter(X,y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X,y)
y_predict = lin_reg.predict(X)

plt.scatter(X,y)
plt.plot(X, y_predict, color = 'r')#注意这里的X不是按顺序的，可是画上去依旧像是一个直线，是因为直线上的各个点来回画来画去。
plt.show()

# %% [markdown]
# ### Solution: add anther feature

# %%
(X**2).shape
# Out:
# (100, 1)

# %%
X2 = np.hstack([X, X**2])

# %%
X2.shape
# Out:
# (100, 2)

# %%
lin_reg2 = LinearRegression()
lin_reg2.fit(X2,y)
y_predict2 = lin_reg2.predict(X2)

plt.scatter(X,y)
plt.plot(X, y_predict2, color = 'r')
plt.show()

# %%
plt.scatter(X,y)
plt.scatter(X, y_predict2, color = 'r')
plt.show()

# %%
plt.scatter(X,y)
plt.plot(np.sort(x), y_predict2[np.argsort(x)], color = 'r') #这里不要用X，而是用x
plt.show()
